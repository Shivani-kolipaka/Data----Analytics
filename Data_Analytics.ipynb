# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivani-kolipaka/Data----Analytics/blob/main/Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TASK1

# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv("/content/employee_data.csv")

# %%
data
# Out:
#       EmpID FirstName    LastName  StartDate   ExitDate  \
# 0      3427     Uriah     Bridges  20-Sep-19        NaN
# 1      3428     Paula       Small  11-Feb-23        NaN
# 2      3429    Edward        Buck  10-Dec-18        NaN
# 3      3430   Michael     Riordan  21-Jun-21        NaN
# 4      3431   Jasmine       Onque  29-Jun-19        NaN
# ...     ...       ...         ...        ...        ...
# 2995   3422    Jakobe    Erickson  22-Jun-22  07-Aug-22
# 2996   3423    Adyson  Strickland  28-Dec-20        NaN
# 2997   3424   Annabel     Wilkins  09-Dec-20  04-Aug-22
# 2998   3425    Kendra       Braun  28-May-19  23-Oct-21
# 2999   3426     Chace        Kerr  27-Apr-22        NaN
#
#                         Title          Supervisor  \
# 0     Production Technician I        Peter Oneill
# 1     Production Technician I     Renee Mccormick
# 2          Area Sales Manager      Crystal Walker
# 3          Area Sales Manager      Rebekah Wright
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   EmpID                       3000 non-null   int64
#  1   FirstName                   3000 non-null   object
#  2   LastName                    3000 non-null   object
#  3   StartDate                   3000 non-null   object
#  4   ExitDate                    1533 non-null   object
#  5   Title                       3000 non-null   object
#  6   Supervisor                  3000 non-null   object
#  7   ADEmail                     3000 non-null   object
#  8   BusinessUnit                3000 non-null   object
#  9   EmployeeStatus              3000 non-null   object
#  10  EmployeeType                3000 non-null   object
#  11  PayZone                     3000 non-null   object
#  12  EmployeeClassificationType  3000 non-null   object
# ...

# %%
data.shape
# Out:
# (3000, 26)

# %%
data=data.dropna()

# %%
data
# Out:
#       EmpID    FirstName  LastName  StartDate   ExitDate  \
# 6      3433        Latia     Costa  06-Apr-22  03-Jul-23
# 7      3434     Sharlene     Terry  06-Nov-20  29-Jan-23
# 9      3436       Joseph   Martins  21-Jan-22  29-Jun-23
# 11     3438       Dheepa    Nguyen  10-Aug-18  04-Nov-19
# 12     3439  Bartholemew  Khemmich  25-May-22  27-Nov-22
# ...     ...          ...       ...        ...        ...
# 2993   3420         Levi    Hayden  10-Oct-20  05-Aug-22
# 2994   3421      Brenden     Leach  09-May-22  08-Sep-22
# 2995   3422       Jakobe  Erickson  22-Jun-22  07-Aug-22
# 2997   3424      Annabel   Wilkins  09-Dec-20  04-Aug-22
# 2998   3425       Kendra     Braun  28-May-19  23-Oct-21
#
#                         Title          Supervisor  \
# 6          Area Sales Manager         Jacob Braun
# 7          Area Sales Manager       Tracy Marquez
# 9          Area Sales Manager      George Jenkins
# 11         Area Sales Manager        Brian Miller
# ...

# %%
data.shape
# Out:
# (1533, 26)

# %% [markdown]
# #TASK2

# %%
import matplotlib.pyplot as plt

# %%
business=data["BusinessUnit"]

# %%
plt.hist(business,bins=20)
# Out:
# (array([156.,   0., 145.,   0., 150.,   0., 157.,   0., 154.,   0.,   0.,
#         157.,   0., 154.,   0., 167.,   0., 150.,   0., 143.]),
#  array([0.  , 0.45, 0.9 , 1.35, 1.8 , 2.25, 2.7 , 3.15, 3.6 , 4.05, 4.5 ,
#         4.95, 5.4 , 5.85, 6.3 , 6.75, 7.2 , 7.65, 8.1 , 8.55, 9.  ]),
#  <BarContainer object of 20 artists>)

# %%
employee=data["EmployeeType"]

# %%
employee
# Out:
# 6       Full-Time
# 7        Contract
# 9       Part-Time
# 11      Full-Time
# 12      Full-Time
#           ...
# 2993     Contract
# 2994    Part-Time
# 2995    Part-Time
# 2997     Contract
# 2998     Contract
# Name: EmployeeType, Length: 1533, dtype: object

# %%
plt.hist(employee)
# Out:
# (array([534.,   0.,   0.,   0.,   0., 514.,   0.,   0.,   0., 485.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
termination=data["TerminationType"]

# %%
termination
# Out:
# 6       Involuntary
# 7       Involuntary
# 9       Resignation
# 11       Retirement
# 12      Involuntary
#            ...
# 2993      Voluntary
# 2994     Retirement
# 2995     Retirement
# 2997    Involuntary
# 2998    Resignation
# Name: TerminationType, Length: 1533, dtype: object

# %%
plt.hist(termination)
# Out:
# (array([388.,   0.,   0., 380.,   0.,   0., 377.,   0.,   0., 388.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
department=data["DepartmentType"]

# %%
department
# Out:
# 6                   Sales
# 7                   Sales
# 9                   Sales
# 11                  Sales
# 12                  Sales
#               ...
# 2993    Production
# 2994    Production
# 2995    Production
# 2997    Production
# 2998    Production
# Name: DepartmentType, Length: 1533, dtype: object

# %%
plt.hist(department)
# Out:
# (array([ 164.,    0.,  224.,    0., 1014.,    0.,   19.,    0.,   64.,
#           48.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #TASK3

# %%
data.describe()
# Out:
#              EmpID  LocationCode  Current Employee Rating
# count  1533.000000   1533.000000              1533.000000
# mean   2511.155251  44586.011742                 2.976517
# std     867.585743  29928.659074                 1.009470
# min    1002.000000   1013.000000                 1.000000
# 25%    1753.000000  17123.000000                 2.000000
# 50%    2503.000000  43998.000000                 3.000000
# 75%    3253.000000  70147.000000                 3.000000
# max    4000.000000  98052.000000                 5.000000

# %%
data.mode()
# Out:
#       EmpID FirstName LastName  StartDate   ExitDate                    Title  \
# 0      1002   Frankie    Smith  10-Aug-18  02-Jul-23  Production Technician I
# 1      1003   Gabriel      NaN        NaN  21-Jul-23                      NaN
# 2      1004    Meadow      NaN        NaN        NaN                      NaN
# 3      1006       NaN      NaN        NaN        NaN                      NaN
# 4      1007       NaN      NaN        NaN        NaN                      NaN
# ...     ...       ...      ...        ...        ...                      ...
# 1528   3992       NaN      NaN        NaN        NaN                      NaN
# 1529   3995       NaN      NaN        NaN        NaN                      NaN
# 1530   3998       NaN      NaN        NaN        NaN                      NaN
# 1531   3999       NaN      NaN        NaN        NaN                      NaN
# 1532   4000       NaN      NaN        NaN        NaN                      NaN
#
# ...

# %%
location=data["LocationCode"]

# %%
location
# Out:
# 6       90007
# 7       97756
# 9       78207
# 11      30428
# 12      80820
#         ...
# 2993    18079
# 2994    57340
# 2995    44500
# 2997     6608
# 2998     3807
# Name: LocationCode, Length: 1533, dtype: int64

# %%
location.median()
# Out:
# 43998.0
